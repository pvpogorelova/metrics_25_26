# %% [markdown]
# <a href="https://colab.research.google.com/github/pvpogorelova/metrics_25_26/blob/main/sem_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Семинар 8.
# Сезонные дамми-переменные.

import pandas as pd # работа с таблицами
import numpy as np # математические функции и матрицы
import matplotlib.pyplot as plt # графики
import seaborn as sns # еще более классные графики
import statsmodels.api as sm # стандартные регрессионные модели
import statsmodels.formula.api as smf # аналогичные модели с синтаксисом в стиле R
import statsmodels.graphics.gofplots as gf # визуализация моделей
import statsmodels.discrete.discrete_model # дискретные модели
from statsmodels.stats.outliers_influence import summary_table # работа с выбросами
from scipy.stats import shapiro # тест Шапиро – Уилка
import math

# %%
# При желании можем настроить графики по своему вкусу, изменив стиль и другие параметры шрифтов и графиков
# (https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html)

plt.rc('font', size=14)
plt.rc('figure', titlesize=15)
plt.rc('axes', labelsize=15)
plt.rc('axes', titlesize=15)

# %%
# Импортируем данные об экономике Баккардии

data = pd.read_excel('Chow_2.xls')
data
# Out:
#     Year  Quarter      C       Y  D1  D2  D3  D4
# 0   2015        1  76.11   92.12   1   0   0   0
# 1   2015        2  75.80   95.01   0   1   0   0
# 2   2015        3  79.54   95.27   0   0   1   0
# 3   2015        4  80.07   97.05   0   0   0   1
# 4   2016        1  81.86   97.06   1   0   0   0
# 5   2016        2  82.57   98.99   0   1   0   0
# 6   2016        3  84.00   99.02   0   0   1   0
# 7   2016        4  81.33   94.34   0   0   0   1
# 8   2017        1  78.64   95.50   1   0   0   0
# 9   2017        2  79.08   98.25   0   1   0   0
# 10  2017        3  80.34   98.88   0   0   1   0
# 11  2017        4  75.90   91.62   0   0   0   1
# 12  2018        1  75.74   93.24   1   0   0   0
# 13  2018        2  76.17   98.50   0   1   0   0
# 14  2018        3  79.32  100.82   0   0   1   0
# 15  2018        4  79.58   99.92   0   0   0   1
# 16  2019        1  84.42  102.46   1   0   0   0
# 17  2019        2  86.14  104.54   0   1   0   0
# 18  2019        3  87.82  102.29   0   0   1   0
# 19  2019        4  86.53  100.28   0   0   0   1
# 20  2020        1  85.21  103.55   1   0   0   0
# 21  2020        2  87.47  105.59   0   1   0   0
# 22  2020        3  86.31  105.79   0   0   1   0
# 23  2020        4  87.06  104.26   0   0   0   1
# 24  2021        1  86.44  104.32   1   0   0   0
# 25  2021        2  87.55  106.41   0   1   0   0
# 26  2021        3  87.28  105.79   0   0   1   0
# 27  2021        4  85.70  104.33   0   0   0   1
# 28  2022        1  84.34  104.73   1   0   0   0
# 29  2022        2  84.33  106.36   0   1   0   0
# 30  2022        3  85.28  107.89   0   0   1   0
# 31  2022        4  86.78  105.27   0   0   0   1

# %%
# Создадим дамми переменные для факторной переменной Quarter (номер квартала)

pd.get_dummies(data, columns = ["Quarter"],drop_first = True)
# Out:
#     Year      C       Y  D1  D2  D3  D4  Quarter_2  Quarter_3  Quarter_4
# 0   2015  76.11   92.12   1   0   0   0      False      False      False
# 1   2015  75.80   95.01   0   1   0   0       True      False      False
# 2   2015  79.54   95.27   0   0   1   0      False       True      False
# 3   2015  80.07   97.05   0   0   0   1      False      False       True
# 4   2016  81.86   97.06   1   0   0   0      False      False      False
# 5   2016  82.57   98.99   0   1   0   0       True      False      False
# 6   2016  84.00   99.02   0   0   1   0      False       True      False
# 7   2016  81.33   94.34   0   0   0   1      False      False       True
# 8   2017  78.64   95.50   1   0   0   0      False      False      False
# 9   2017  79.08   98.25   0   1   0   0       True      False      False
# 10  2017  80.34   98.88   0   0   1   0      False       True      False
# 11  2017  75.90   91.62   0   0   0   1      False      False       True
# 12  2018  75.74   93.24   1   0   0   0      False      False      False
# 13  2018  76.17   98.50   0   1   0   0       True      False      False
# 14  2018  79.32  100.82   0   0   1   0      False       True      False
# 15  2018  79.58   99.92   0   0   0   1      False      False       True
# 16  2019  84.42  102.46   1   0   0   0      False      False      False
# 17  2019  86.14  104.54   0   1   0   0       True      False      False
# 18  2019  87.82  102.29   0   0   1   0      False       True      False
# 19  2019  86.53  100.28   0   0   0   1      False      False       True
# 20  2020  85.21  103.55   1   0   0   0      False      False      False
# 21  2020  87.47  105.59   0   1   0   0       True      False      False
# 22  2020  86.31  105.79   0   0   1   0      False       True      False
# 23  2020  87.06  104.26   0   0   0   1      False      False       True
# 24  2021  86.44  104.32   1   0   0   0      False      False      False
# 25  2021  87.55  106.41   0   1   0   0       True      False      False
# 26  2021  87.28  105.79   0   0   1   0      False       True      False
# 27  2021  85.70  104.33   0   0   0   1      False      False       True
# 28  2022  84.34  104.73   1   0   0   0      False      False      False
# 29  2022  84.33  106.36   0   1   0   0       True      False      False
# 30  2022  85.28  107.89   0   0   1   0      False       True      False
# 31  2022  86.78  105.27   0   0   0   1      False      False       True

# %%
# Построим диаграмму рассеяния потребления от дохода, учитывая номер квартала, к которому относится наблюдение

sns.pairplot(data,x_vars = ['Y'],y_vars=['C'],hue = 'Quarter')

# %%
# Оценим модель регрессии для потребления, используя в качестве объясняющих переменных доход и квартал (сезонность)

model_1 = smf.ols('C ~ Y + D2 + D3 + D4', data = data).fit()
print(model_1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      C   R-squared:                       0.771
# Model:                            OLS   Adj. R-squared:                  0.738
# Method:                 Least Squares   F-statistic:                     22.79
# Date:                Thu, 23 Oct 2025   Prob (F-statistic):           2.53e-08
# Time:                        12:23:57   Log-Likelihood:                -66.356
# No. Observations:                  32   AIC:                             142.7
# Df Residuals:                      27   BIC:                             150.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.8255      8.275      0.583      0.565     -12.153      21.804
# Y              0.7745      0.083      9.315      0.000       0.604       0.945
# D2            -1.2073      1.069     -1.129      0.269      -3.402       0.987
# D3            -0.0631      1.074     -0.059      0.954      -2.267       2.140
# D4             0.8778      1.048      0.837      0.410      -1.273       3.029
# ==============================================================================
# Omnibus:                        0.261   Durbin-Watson:                   0.722
# Prob(Omnibus):                  0.877   Jarque-Bera (JB):                0.451
# Skew:                          -0.114   Prob(JB):                        0.798
# Kurtosis:                       2.465   Cond. No.                     2.25e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.25e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Проверим гипотезу об отсутствии сезонности

hypotheses = '(D2 = D3 = D4 = 0)' # формулируем гипотезу H_0
print(model_1.f_test(r_matrix = hypotheses)) # тестируем гипотезу с помощью F-теста
# Out:
# <F test: F=1.2961278194597616, p=0.29595511594426166, df_denom=27, df_num=3>

# %%
# Оценим эту же модель, но включим все дамми на сезонность, исключив константу

model_1_wc = smf.ols('C ~ 0 + Y + D1 + D2 + D3 + D4', data = data).fit()
print(model_1_wc.summary())# получили тот же самый результат, что и в модели model_1
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      C   R-squared:                       0.771
# Model:                            OLS   Adj. R-squared:                  0.738
# Method:                 Least Squares   F-statistic:                     22.79
# Date:                Thu, 23 Oct 2025   Prob (F-statistic):           2.53e-08
# Time:                        12:24:20   Log-Likelihood:                -66.356
# No. Observations:                  32   AIC:                             142.7
# Df Residuals:                      27   BIC:                             150.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Y              0.7745      0.083      9.315      0.000       0.604       0.945
# D1             4.8255      8.275      0.583      0.565     -12.153      21.804
# D2             3.6182      8.489      0.426      0.673     -13.799      21.035
# D3             4.7624      8.510      0.560      0.580     -12.699      22.224
# D4             5.7033      8.317      0.686      0.499     -11.362      22.768
# ==============================================================================
# Omnibus:                        0.261   Durbin-Watson:                   0.722
# Prob(Omnibus):                  0.877   Jarque-Bera (JB):                0.451
# Skew:                          -0.114   Prob(JB):                        0.798
# Kurtosis:                       2.465   Cond. No.                     4.55e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.55e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Создадим переменные взаимодействия (перекрестные переменные), чтобы учесть возможную разную зависимость потребления
# от дохода в разные кварталы

data['yq2'] = data['Y']*data['D2']
data['yq3'] = data['Y']*data['D3']
data['yq4'] = data['Y']*data['D4']

data
# Out:
#     Year  Quarter      C       Y  D1  D2  D3  D4     yq2     yq3     yq4
# 0   2015        1  76.11   92.12   1   0   0   0    0.00    0.00    0.00
# 1   2015        2  75.80   95.01   0   1   0   0   95.01    0.00    0.00
# 2   2015        3  79.54   95.27   0   0   1   0    0.00   95.27    0.00
# 3   2015        4  80.07   97.05   0   0   0   1    0.00    0.00   97.05
# 4   2016        1  81.86   97.06   1   0   0   0    0.00    0.00    0.00
# 5   2016        2  82.57   98.99   0   1   0   0   98.99    0.00    0.00
# 6   2016        3  84.00   99.02   0   0   1   0    0.00   99.02    0.00
# 7   2016        4  81.33   94.34   0   0   0   1    0.00    0.00   94.34
# 8   2017        1  78.64   95.50   1   0   0   0    0.00    0.00    0.00
# 9   2017        2  79.08   98.25   0   1   0   0   98.25    0.00    0.00
# 10  2017        3  80.34   98.88   0   0   1   0    0.00   98.88    0.00
# 11  2017        4  75.90   91.62   0   0   0   1    0.00    0.00   91.62
# 12  2018        1  75.74   93.24   1   0   0   0    0.00    0.00    0.00
# 13  2018        2  76.17   98.50   0   1   0   0   98.50    0.00    0.00
# 14  2018        3  79.32  100.82   0   0   1   0    0.00  100.82    0.00
# 15  2018        4  79.58   99.92   0   0   0   1    0.00    0.00   99.92
# 16  2019        1  84.42  102.46   1   0   0   0    0.00    0.00    0.00
# 17  2019        2  86.14  104.54   0   1   0   0  104.54    0.00    0.00
# 18  2019        3  87.82  102.29   0   0   1   0    0.00  102.29    0.00
# 19  2019        4  86.53  100.28   0   0   0   1    0.00    0.00  100.28
# 20  2020        1  85.21  103.55   1   0   0   0    0.00    0.00    0.00
# 21  2020        2  87.47  105.59   0   1   0   0  105.59    0.00    0.00
# 22  2020        3  86.31  105.79   0   0   1   0    0.00  105.79    0.00
# 23  2020        4  87.06  104.26   0   0   0   1    0.00    0.00  104.26
# 24  2021        1  86.44  104.32   1   0   0   0    0.00    0.00    0.00
# 25  2021        2  87.55  106.41   0   1   0   0  106.41    0.00    0.00
# 26  2021        3  87.28  105.79   0   0   1   0    0.00  105.79    0.00
# 27  2021        4  85.70  104.33   0   0   0   1    0.00    0.00  104.33
# 28  2022        1  84.34  104.73   1   0   0   0    0.00    0.00    0.00
# 29  2022        2  84.33  106.36   0   1   0   0  106.36    0.00    0.00
# 30  2022        3  85.28  107.89   0   0   1   0    0.00  107.89    0.00
# 31  2022        4  86.78  105.27   0   0   0   1    0.00    0.00  105.27

# %%
# Оценим модель, учитывающую переменные взаимодействия

model_2 = smf.ols('C ~ Y + D2 + D3 + D4 + yq2 + yq3 + yq4', data = data).fit()
print(model_2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      C   R-squared:                       0.792
# Model:                            OLS   Adj. R-squared:                  0.731
# Method:                 Least Squares   F-statistic:                     13.04
# Date:                Thu, 23 Oct 2025   Prob (F-statistic):           8.19e-07
# Time:                        12:24:53   Log-Likelihood:                -64.868
# No. Observations:                  32   AIC:                             145.7
# Df Residuals:                      24   BIC:                             157.5
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.9411     15.264      0.258      0.798     -27.562      35.445
# Y              0.7834      0.154      5.094      0.000       0.466       1.101
# D2           -21.3432     23.725     -0.900      0.377     -70.309      27.623
# D3            19.0521     24.430      0.780      0.443     -31.369      69.473
# D4             6.2586     22.121      0.283      0.780     -39.396      51.914
# yq2            0.1978      0.236      0.839      0.409      -0.288       0.684
# yq3           -0.1877      0.242     -0.775      0.446      -0.687       0.312
# yq4           -0.0541      0.222     -0.243      0.810      -0.513       0.405
# ==============================================================================
# Omnibus:                        0.037   Durbin-Watson:                   0.626
# Prob(Omnibus):                  0.982   Jarque-Bera (JB):                0.161
# Skew:                          -0.071   Prob(JB):                        0.923
# Kurtosis:                       2.683   Cond. No.                     1.01e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.01e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # **Анализ влиятельных наблюдений и выбросов**

# %%
from statsmodels.stats.outliers_influence import summary_table # работа с выбросами

# %%
# Выведем таблицу, содержащую различные показатели

influence = model_1.get_influence()
inf_sum = influence.summary_frame()

print(inf_sum.head())
# Out:
#    dfb_Intercept     dfb_Y    dfb_D2    dfb_D3    dfb_D4   cooks_d  \
# 0      -0.011159  0.010054  0.006841  0.006608  0.008630  0.000055
# 1      -0.218412  0.219292 -0.246155 -0.048321 -0.008891  0.027097
# 2       0.153718 -0.154338  0.031004  0.175586  0.006257  0.013557
# 3      -0.044271  0.044450 -0.008929 -0.009794 -0.110091  0.005257
# 4       0.115655 -0.083646 -0.233479 -0.230780 -0.251890  0.027605
#
#    standard_resid  hat_diag  dffits_internal  student_resid    dffits
# 0       -0.032931  0.202221        -0.016580      -0.032317 -0.016270
# 1       -0.746409  0.195614        -0.368082      -0.740132 -0.364987
# 2        0.527866  0.195667         0.260354       0.520692  0.256816
# 3       -0.409472  0.135513        -0.162120      -0.403071 -0.159585
# 4        0.953940  0.131699         0.371516       0.952293  0.370874

# %%
# Объединим исходные данные с таблицей показателей

results = pd.concat([data, inf_sum], axis = 1)
print(results)
# Out:
#     Year  Quarter      C       Y  D1  D2  D3  D4     yq2     yq3  ...  \
# 0   2015        1  76.11   92.12   1   0   0   0    0.00    0.00  ...
# 1   2015        2  75.80   95.01   0   1   0   0   95.01    0.00  ...
# 2   2015        3  79.54   95.27   0   0   1   0    0.00   95.27  ...
# 3   2015        4  80.07   97.05   0   0   0   1    0.00    0.00  ...
# 4   2016        1  81.86   97.06   1   0   0   0    0.00    0.00  ...
# 5   2016        2  82.57   98.99   0   1   0   0   98.99    0.00  ...
# 6   2016        3  84.00   99.02   0   0   1   0    0.00   99.02  ...
# 7   2016        4  81.33   94.34   0   0   0   1    0.00    0.00  ...
# 8   2017        1  78.64   95.50   1   0   0   0    0.00    0.00  ...
# 9   2017        2  79.08   98.25   0   1   0   0   98.25    0.00  ...
# 10  2017        3  80.34   98.88   0   0   1   0    0.00   98.88  ...
# 11  2017        4  75.90   91.62   0   0   0   1    0.00    0.00  ...
# 12  2018        1  75.74   93.24   1   0   0   0    0.00    0.00  ...
# 13  2018        2  76.17   98.50   0   1   0   0   98.50    0.00  ...
# 14  2018        3  79.32  100.82   0   0   1   0    0.00  100.82  ...
# 15  2018        4  79.58   99.92   0   0   0   1    0.00    0.00  ...
# 16  2019        1  84.42  102.46   1   0   0   0    0.00    0.00  ...
# 17  2019        2  86.14  104.54   0   1   0   0  104.54    0.00  ...
# 18  2019        3  87.82  102.29   0   0   1   0    0.00  102.29  ...
# 19  2019        4  86.53  100.28   0   0   0   1    0.00    0.00  ...
# 20  2020        1  85.21  103.55   1   0   0   0    0.00    0.00  ...
# 21  2020        2  87.47  105.59   0   1   0   0  105.59    0.00  ...
# 22  2020        3  86.31  105.79   0   0   1   0    0.00  105.79  ...
# 23  2020        4  87.06  104.26   0   0   0   1    0.00    0.00  ...
# 24  2021        1  86.44  104.32   1   0   0   0    0.00    0.00  ...
# 25  2021        2  87.55  106.41   0   1   0   0  106.41    0.00  ...
# 26  2021        3  87.28  105.79   0   0   1   0    0.00  105.79  ...
# 27  2021        4  85.70  104.33   0   0   0   1    0.00    0.00  ...
# 28  2022        1  84.34  104.73   1   0   0   0    0.00    0.00  ...
# 29  2022        2  84.33  106.36   0   1   0   0  106.36    0.00  ...
# 30  2022        3  85.28  107.89   0   0   1   0    0.00  107.89  ...
# 31  2022        4  86.78  105.27   0   0   0   1    0.00    0.00  ...
#
#        dfb_Y    dfb_D2    dfb_D3    dfb_D4   cooks_d  standard_resid  \
# 0   0.010054  0.006841  0.006608  0.008630  0.000055       -0.032931
# 1   0.219292 -0.246155 -0.048321 -0.008891  0.027097       -0.746409
# 2  -0.154338  0.031004  0.175586  0.006257  0.013557        0.527866
# 3   0.044450 -0.008929 -0.009794 -0.110091  0.005257       -0.409472
# 4  -0.083646 -0.233479 -0.230780 -0.251890  0.027605        0.953940
# 5  -0.137159  0.339180  0.030223  0.005561  0.043598        1.173718
# 6  -0.167521  0.033653  0.386012  0.006792  0.055282        1.310166
# 7  -0.313944  0.063067  0.069177  0.386027  0.073224        1.341114
# 8   0.011776  0.017696  0.017381  0.019985  0.000203       -0.077151
# 9   0.047507 -0.094370 -0.010468 -0.001926  0.003569       -0.325957
# 10  0.067362 -0.013532 -0.148856 -0.002731  0.008696       -0.516766
# 11  0.147167 -0.029564 -0.032428 -0.121562  0.009994       -0.413530
# 12  0.174629  0.148123  0.143940  0.179782  0.020500       -0.684500
# 13  0.279047 -0.593162 -0.061488 -0.011314  0.121707       -1.923935
# 14  0.091964 -0.018474 -0.512200 -0.003729  0.094498       -1.801560
# 15 -0.022743  0.004569  0.005011 -0.499189  0.091790       -1.791334
# 16  0.017378 -0.035624 -0.035825 -0.033479  0.000509        0.123776
# 17  0.096217  0.190212 -0.021201 -0.003901  0.020432        0.800023
# 18  0.028255 -0.005676  0.534243 -0.001146  0.109582        1.956958
# 19  0.045680 -0.009176 -0.010066  0.443080  0.074818        1.613368
# 20  0.018130 -0.028913 -0.029158 -0.026511  0.000345        0.096595
# 21  0.179690  0.249433 -0.039594 -0.007285  0.040206        1.072568
# 22 -0.032183  0.006465 -0.044661  0.001305  0.001382       -0.199479
# 23  0.062285 -0.012512 -0.013724  0.082221  0.003780        0.316520
# 24  0.095436 -0.132490 -0.133862 -0.119451  0.007399        0.428744
# 25  0.159851  0.177614 -0.035223 -0.006481  0.023782        0.790580
# 26  0.048785 -0.009800  0.067701 -0.001978  0.003171        0.302097
# 27 -0.083998  0.016874  0.018509 -0.109181  0.006695       -0.419650
# 28 -0.204445  0.266072  0.269088  0.237785  0.029796       -0.839456
# 29 -0.173493 -0.195217  0.038229  0.007034  0.028354       -0.865601
# 30 -0.429382  0.086257 -0.350989  0.017409  0.113076       -1.603705
# 31 -0.057709  0.011593  0.012716 -0.062111  0.002415       -0.238560
#
#     hat_diag  dffits_internal  student_resid    dffits
# 0   0.202221        -0.016580      -0.032317 -0.016270
# 1   0.195614        -0.368082      -0.740132 -0.364987
# 2   0.195667         0.260354       0.520692  0.256816
# 3   0.135513        -0.162120      -0.403071 -0.159585
# 4   0.131699         0.371516       0.952293  0.370874
# 5   0.136619         0.466894       1.182335  0.470321
# 6   0.138693         0.525745       1.328602  0.533143
# 7   0.169132         0.605080       1.362197  0.614592
# 8   0.145666        -0.031857      -0.075717 -0.031265
# 9   0.143812        -0.133590      -0.320495 -0.131351
# 10  0.140024        -0.208522      -0.509633 -0.205644
# 11  0.226135        -0.223541      -0.407091 -0.220061
# 12  0.179495        -0.320153      -0.677609 -0.316931
# 13  0.141189        -0.780086      -2.032419 -0.824072
# 14  0.127078        -0.687380      -1.884793 -0.719137
# 15  0.125129        -0.677460      -1.872646 -0.708211
# 16  0.142542         0.050466       0.121497  0.049537
# 17  0.137646         0.319625       0.794542  0.317436
# 18  0.125163         0.740210       2.073013  0.784107
# 19  0.125658         0.611628       1.665526  0.631401
# 20  0.155871         0.041508       0.094806  0.040739
# 21  0.148754         0.448364       1.075684  0.449667
# 22  0.147995        -0.083138      -0.195895 -0.081644
# 23  0.158704         0.137474       0.311181  0.135156
# 24  0.167542         0.192344       0.422169  0.189394
# 25  0.159843         0.344836       0.784939  0.342376
# 26  0.147995         0.125907       0.296952  0.123762
# 27  0.159732        -0.182968      -0.413155 -0.180136
# 28  0.174519        -0.385980      -0.834729 -0.383807
# 29  0.159106        -0.376522      -0.861457 -0.374720
# 30  0.180215        -0.751917      -1.654497 -0.775732
# 31  0.175028        -0.109883      -0.234348 -0.107943
#
# [32 rows x 22 columns]

# %%
# 1. Показатель воздействия наблюдения или «разбалансировки»: точки левериджа (p_ii - показатель влияния, рычаг)

leverage = influence.hat_matrix_diag
leverage
# Out:
# array([0.20222109, 0.19561436, 0.19566709, 0.1355131 , 0.13169912,
#        0.13661901, 0.13869322, 0.1691323 , 0.14566553, 0.14381222,
#        0.14002433, 0.22613495, 0.17949461, 0.14118917, 0.12707817,
#        0.12512904, 0.14254172, 0.13764599, 0.12516252, 0.1256577 ,
#        0.15587072, 0.14875375, 0.14799538, 0.1587045 , 0.16754208,
#        0.15984321, 0.14799538, 0.15973218, 0.17451859, 0.15910639,
#        0.18021492, 0.17502766])

# %%
# Определим пороговое значение для точек левериджа
cutoff_leverage = (2*5)/32
cutoff_leverage
# Out:
# 0.3125

# %%
# Выведем номера всех точек левериджа
high_leverage = pd.DataFrame((results[abs(leverage) > cutoff_leverage]))
high_leverage
# Out:
# Empty DataFrame
# Columns: [Year, Quarter, C, Y, D1, D2, D3, D4, yq2, yq3, yq4, dfb_Intercept, dfb_Y, dfb_D2, dfb_D3, dfb_D4, cooks_d, standard_resid, hat_diag, dffits_internal, student_resid, dffits]
# Index: []
#
# [0 rows x 22 columns]

# %%
# 2. Анализ влиятельности наблюдения: DFFITS

dffits = influence.dffits
print(dffits)

# %%
# пороговое значение для DFFITS: cutoff = 2*sqrt(k/n)

cutoff_dffits = 2*math.sqrt(5/32)
print(cutoff_dffits)
# Out:
# 0.7905694150420949

# %%
# Выведем наблюдения, являющиеся влиятельными согласно DFFITS

dffits_high = pd.DataFrame((results[abs(inf_sum.dffits) > cutoff_dffits]))
dffits_high
# Out:
#     Year  Quarter      C     Y  D1  D2  D3  D4   yq2  yq3  ...     dfb_Y  \
# 13  2018        2  76.17  98.5   0   1   0   0  98.5  0.0  ...  0.279047
#
#       dfb_D2    dfb_D3    dfb_D4   cooks_d  standard_resid  hat_diag  \
# 13 -0.593162 -0.061488 -0.011314  0.121707       -1.923935  0.141189
#
#     dffits_internal  student_resid    dffits
# 13        -0.780086      -2.032419 -0.824072
#
# [1 rows x 22 columns]

# %%
# 3. Анализ влиятельности наблюдения: DFBETAS

cut_off = 2 / math.sqrt(32)
print(cut_off)
# Out:
# 0.35355339059327373

# %%
plt.scatter(results.C, results.dfb_Y, color = "red", marker = "o")
plt.scatter(results.C, results.dfb_D2, color = "green", marker = "o")
plt.scatter(results.C, results.dfb_D3, color = "blue", marker = "o")
plt.scatter(results.C, results.dfb_D4, color = "black", marker = "o")
plt.plot((70,100),(0.354, 0.354), '-.r*')
plt.plot((70,100),(-0.354, -0.354), '-.r*')

# %%
# Выведем номера всех влиятельных наблюдений согласно DFBETAS для переменной Y

high_dfby = pd.DataFrame((results[abs(results.dfb_Y) > cut_off]))
high_dfby
# Out:
#     Year  Quarter      C       Y  D1  D2  D3  D4  yq2     yq3  ...     dfb_Y  \
# 30  2022        3  85.28  107.89   0   0   1   0  0.0  107.89  ... -0.429382
#
#       dfb_D2    dfb_D3    dfb_D4   cooks_d  standard_resid  hat_diag  \
# 30  0.086257 -0.350989  0.017409  0.113076       -1.603705  0.180215
#
#     dffits_internal  student_resid    dffits
# 30        -0.751917      -1.654497 -0.775732
#
# [1 rows x 22 columns]

# %%
# Выведем номера всех влиятельных наблюдений согласно DFBETAS для переменной D2

high_dfbd2 = pd.DataFrame((results[abs(results.dfb_D2) > cut_off]))
high_dfbd2
# Out:
#     Year  Quarter      C     Y  D1  D2  D3  D4   yq2  yq3  ...     dfb_Y  \
# 13  2018        2  76.17  98.5   0   1   0   0  98.5  0.0  ...  0.279047
#
#       dfb_D2    dfb_D3    dfb_D4   cooks_d  standard_resid  hat_diag  \
# 13 -0.593162 -0.061488 -0.011314  0.121707       -1.923935  0.141189
#
#     dffits_internal  student_resid    dffits
# 13        -0.780086      -2.032419 -0.824072
#
# [1 rows x 22 columns]

# %%
# Выведем номера всех влиятельных наблюдений согласно DFBETAS для переменной D3

high_dfbd3 = pd.DataFrame((results[abs(results.dfb_D3) > cut_off]))
high_dfbd3
# Out:
#     Year  Quarter      C       Y  D1  D2  D3  D4  yq2     yq3  ...     dfb_Y  \
# 6   2016        3  84.00   99.02   0   0   1   0  0.0   99.02  ... -0.167521
# 14  2018        3  79.32  100.82   0   0   1   0  0.0  100.82  ...  0.091964
# 18  2019        3  87.82  102.29   0   0   1   0  0.0  102.29  ...  0.028255
#
#       dfb_D2    dfb_D3    dfb_D4   cooks_d  standard_resid  hat_diag  \
# 6   0.033653  0.386012  0.006792  0.055282        1.310166  0.138693
# 14 -0.018474 -0.512200 -0.003729  0.094498       -1.801560  0.127078
# 18 -0.005676  0.534243 -0.001146  0.109582        1.956958  0.125163
#
#     dffits_internal  student_resid    dffits
# 6          0.525745       1.328602  0.533143
# 14        -0.687380      -1.884793 -0.719137
# 18         0.740210       2.073013  0.784107
#
# [3 rows x 22 columns]

# %%
# Выведем номера всех влиятельных наблюдений согласно DFBETAS для переменной D4

high_dfbd4 = pd.DataFrame((results[abs(results.dfb_D4) > cut_off]))
high_dfbd4
# Out:
#     Year  Quarter      C       Y  D1  D2  D3  D4  yq2  yq3  ...     dfb_Y  \
# 7   2016        4  81.33   94.34   0   0   0   1  0.0  0.0  ... -0.313944
# 15  2018        4  79.58   99.92   0   0   0   1  0.0  0.0  ... -0.022743
# 19  2019        4  86.53  100.28   0   0   0   1  0.0  0.0  ...  0.045680
#
#       dfb_D2    dfb_D3    dfb_D4   cooks_d  standard_resid  hat_diag  \
# 7   0.063067  0.069177  0.386027  0.073224        1.341114  0.169132
# 15  0.004569  0.005011 -0.499189  0.091790       -1.791334  0.125129
# 19 -0.009176 -0.010066  0.443080  0.074818        1.613368  0.125658
#
#     dffits_internal  student_resid    dffits
# 7          0.605080       1.362197  0.614592
# 15        -0.677460      -1.872646 -0.708211
# 19         0.611628       1.665526  0.631401
#
# [3 rows x 22 columns]

# %%
# 4. Анализ выбросов: стьюдентизированные остатки

student_resid = influence.resid_studentized_external
print(student_resid)
# Out:
# [-0.03231652 -0.74013159  0.52069227 -0.40307082  0.95229311  1.18233486
#   1.32860183  1.36219667 -0.07571695 -0.32049503 -0.5096329  -0.40709052
#  -0.67760929 -2.03241942 -1.88479273 -1.87264628  0.12149683  0.79454158
#   2.07301337  1.66552602  0.09480606  1.07568366 -0.19589484  0.31118131
#   0.42216853  0.78493945  0.29695178 -0.41315495 -0.83472876 -0.86145684
#  -1.65449729 -0.23434812]

# %%
# определим критическое значение для стьюдентизированных остатков

from scipy import stats
crit = stats.t(df=26).ppf((0.95))
print(crit)
# Out:
# 1.7056179197592727

# %%
# Выведем номера всех возможных выбросов согласно стьюдентизированным остаткам

high_stud_res = pd.DataFrame((results[abs(student_resid) > crit]))
high_stud_res
# Out:
#     Year  Quarter      C       Y  D1  D2  D3  D4   yq2     yq3  ...     dfb_Y  \
# 13  2018        2  76.17   98.50   0   1   0   0  98.5    0.00  ...  0.279047
# 14  2018        3  79.32  100.82   0   0   1   0   0.0  100.82  ...  0.091964
# 15  2018        4  79.58   99.92   0   0   0   1   0.0    0.00  ... -0.022743
# 18  2019        3  87.82  102.29   0   0   1   0   0.0  102.29  ...  0.028255
#
#       dfb_D2    dfb_D3    dfb_D4   cooks_d  standard_resid  hat_diag  \
# 13 -0.593162 -0.061488 -0.011314  0.121707       -1.923935  0.141189
# 14 -0.018474 -0.512200 -0.003729  0.094498       -1.801560  0.127078
# 15  0.004569  0.005011 -0.499189  0.091790       -1.791334  0.125129
# 18 -0.005676  0.534243 -0.001146  0.109582        1.956958  0.125163
#
#     dffits_internal  student_resid    dffits
# 13        -0.780086      -2.032419 -0.824072
# 14        -0.687380      -1.884793 -0.719137
# 15        -0.677460      -1.872646 -0.708211
# 18         0.740210       2.073013  0.784107
#
# [4 rows x 22 columns]

# %%
# Удалим влиятельные наблюдения и выбросы и переоценим регерссию заново

data_new = data.drop([13,14,15,18])
data_new
# Out:
#     Year  Quarter      C       Y  D1  D2  D3  D4     yq2     yq3     yq4
# 0   2015        1  76.11   92.12   1   0   0   0    0.00    0.00    0.00
# 1   2015        2  75.80   95.01   0   1   0   0   95.01    0.00    0.00
# 2   2015        3  79.54   95.27   0   0   1   0    0.00   95.27    0.00
# 3   2015        4  80.07   97.05   0   0   0   1    0.00    0.00   97.05
# 4   2016        1  81.86   97.06   1   0   0   0    0.00    0.00    0.00
# 5   2016        2  82.57   98.99   0   1   0   0   98.99    0.00    0.00
# 6   2016        3  84.00   99.02   0   0   1   0    0.00   99.02    0.00
# 7   2016        4  81.33   94.34   0   0   0   1    0.00    0.00   94.34
# 8   2017        1  78.64   95.50   1   0   0   0    0.00    0.00    0.00
# 9   2017        2  79.08   98.25   0   1   0   0   98.25    0.00    0.00
# 10  2017        3  80.34   98.88   0   0   1   0    0.00   98.88    0.00
# 11  2017        4  75.90   91.62   0   0   0   1    0.00    0.00   91.62
# 12  2018        1  75.74   93.24   1   0   0   0    0.00    0.00    0.00
# 16  2019        1  84.42  102.46   1   0   0   0    0.00    0.00    0.00
# 17  2019        2  86.14  104.54   0   1   0   0  104.54    0.00    0.00
# 19  2019        4  86.53  100.28   0   0   0   1    0.00    0.00  100.28
# 20  2020        1  85.21  103.55   1   0   0   0    0.00    0.00    0.00
# 21  2020        2  87.47  105.59   0   1   0   0  105.59    0.00    0.00
# 22  2020        3  86.31  105.79   0   0   1   0    0.00  105.79    0.00
# 23  2020        4  87.06  104.26   0   0   0   1    0.00    0.00  104.26
# 24  2021        1  86.44  104.32   1   0   0   0    0.00    0.00    0.00
# 25  2021        2  87.55  106.41   0   1   0   0  106.41    0.00    0.00
# 26  2021        3  87.28  105.79   0   0   1   0    0.00  105.79    0.00
# 27  2021        4  85.70  104.33   0   0   0   1    0.00    0.00  104.33
# 28  2022        1  84.34  104.73   1   0   0   0    0.00    0.00    0.00
# 29  2022        2  84.33  106.36   0   1   0   0  106.36    0.00    0.00
# 30  2022        3  85.28  107.89   0   0   1   0    0.00  107.89    0.00
# 31  2022        4  86.78  105.27   0   0   0   1    0.00    0.00  105.27

# %%
# Оценим модель на новой выборке и сравним результаты оценивания с предыдущими, полученными по полной выборке
reg_new = smf.ols('C ~ Y + D2 + D3 + D4', data = data_new).fit()
print(reg_new.summary())
print(model_1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      C   R-squared:                       0.858
# Model:                            OLS   Adj. R-squared:                  0.833
# Method:                 Least Squares   F-statistic:                     34.65
# Date:                Thu, 23 Oct 2025   Prob (F-statistic):           1.99e-09
# Time:                        12:56:41   Log-Likelihood:                -50.590
# No. Observations:                  28   AIC:                             111.2
# Df Residuals:                      23   BIC:                             117.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.6607      6.491      1.180      0.250      -5.766      21.088
# Y              0.7459      0.065     11.436      0.000       0.611       0.881
# D2            -0.5867      0.865     -0.679      0.504      -2.375       1.202
# D3            -0.0292      0.900     -0.032      0.974      -1.890       1.832
# D4             1.3927      0.842      1.654      0.112      -0.349       3.135
# ==============================================================================
# Omnibus:                        2.409   Durbin-Watson:                   1.011
# Prob(Omnibus):                  0.300   Jarque-Bera (JB):                1.221
# Skew:                           0.031   Prob(JB):                        0.543
# Kurtosis:                       1.979   Cond. No.                     2.13e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.13e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      C   R-squared:                       0.771
# Model:                            OLS   Adj. R-squared:                  0.738
# Method:                 Least Squares   F-statistic:                     22.79
# Date:                Thu, 23 Oct 2025   Prob (F-statistic):           2.53e-08
# Time:                        12:56:41   Log-Likelihood:                -66.356
# No. Observations:                  32   AIC:                             142.7
# Df Residuals:                      27   BIC:                             150.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.8255      8.275      0.583      0.565     -12.153      21.804
# Y              0.7745      0.083      9.315      0.000       0.604       0.945
# D2            -1.2073      1.069     -1.129      0.269      -3.402       0.987
# D3            -0.0631      1.074     -0.059      0.954      -2.267       2.140
# D4             0.8778      1.048      0.837      0.410      -1.273       3.029
# ==============================================================================
# Omnibus:                        0.261   Durbin-Watson:                   0.722
# Prob(Omnibus):                  0.877   Jarque-Bera (JB):                0.451
# Skew:                          -0.114   Prob(JB):                        0.798
# Kurtosis:                       2.465   Cond. No.                     2.25e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.25e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Не спешите удалять нетипичные наблюдения! Возможно, стоит их замоделировать путём введения dummy-переменной.

# %%
data['outlier'] = 0
data.loc[[13, 14, 15, 18], 'outlier'] = 1 # дамми-переменная на outliers

# %%
# Оценим модель на новой выборке и сравним результаты оценивания с предыдущими, полученными по полной выборке
reg_do = smf.ols('C ~ Y + D2 + D3 + D4 + outlier', data = data).fit()
print(reg_do.summary())
print(model_1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      C   R-squared:                       0.800
# Model:                            OLS   Adj. R-squared:                  0.762
# Method:                 Least Squares   F-statistic:                     20.83
# Date:                Thu, 23 Oct 2025   Prob (F-statistic):           2.40e-08
# Time:                        12:59:38   Log-Likelihood:                -64.204
# No. Observations:                  32   AIC:                             140.4
# Df Residuals:                      26   BIC:                             149.2
# Df Model:                           5
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        6.0828      7.911      0.769      0.449     -10.178      22.344
# Y                0.7618      0.079      9.584      0.000       0.598       0.925
# D2              -0.9059      1.031     -0.879      0.388      -3.025       1.213
# D3               0.5103      1.065      0.479      0.636      -1.680       2.700
# D4               1.1529      1.009      1.143      0.264      -0.921       3.227
# new_variable    -2.1493      1.111     -1.934      0.064      -4.433       0.135
# ==============================================================================
# Omnibus:                        5.508   Durbin-Watson:                   0.837
# Prob(Omnibus):                  0.064   Jarque-Bera (JB):                3.883
# Skew:                           0.760   Prob(JB):                        0.144
# Kurtosis:                       3.774   Cond. No.                     2.26e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.26e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      C   R-squared:                       0.771
# Model:                            OLS   Adj. R-squared:                  0.738
# Method:                 Least Squares   F-statistic:                     22.79
# Date:                Thu, 23 Oct 2025   Prob (F-statistic):           2.53e-08
# Time:                        12:59:38   Log-Likelihood:                -66.356
# No. Observations:                  32   AIC:                             142.7
# Df Residuals:                      27   BIC:                             150.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.8255      8.275      0.583      0.565     -12.153      21.804
# Y              0.7745      0.083      9.315      0.000       0.604       0.945
# D2            -1.2073      1.069     -1.129      0.269      -3.402       0.987
# D3            -0.0631      1.074     -0.059      0.954      -2.267       2.140
# D4             0.8778      1.048      0.837      0.410      -1.273       3.029
# ==============================================================================
# Omnibus:                        0.261   Durbin-Watson:                   0.722
# Prob(Omnibus):                  0.877   Jarque-Bera (JB):                0.451
# Skew:                          -0.114   Prob(JB):                        0.798
# Kurtosis:                       2.465   Cond. No.                     2.25e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.25e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Если вы хотите сравнить переменные по силе поздействия на зависимую переменную, помните, что необходимо перейти к стандартизированным показателям. В этом случае интерпретация оценки коэффициента $\beta_j$ перед переменной $X_j$ будет следующей: при увеличении $X_j$ на 1 стандартное отклонение зависимая переменная $y$ при прочих равных в среднем изменится на $\hat{\beta}_j$ стандартных отклонений.

# %%
# Стандартизируем переменные
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

data_scale=data.copy()
data_scale=pd.DataFrame(scaler.fit_transform(data_scale), columns=data_scale.columns)
data_scale
# Out:
#         Year   Quarter         C         Y        D1        D2        D3  \
# 0  -1.527525 -1.341641 -1.623730 -1.834929  1.732051 -0.577350 -0.577350
# 1  -1.527525 -0.447214 -1.700729 -1.210157 -0.577350  1.732051 -0.577350
# 2  -1.527525  0.447214 -0.771774 -1.153949 -0.577350 -0.577350  1.732051
# 3  -1.527525  1.341641 -0.640131 -0.769142 -0.577350 -0.577350 -0.577350
# 4  -1.091089 -1.341641 -0.195524 -0.766980  1.732051 -0.577350 -0.577350
# 5  -1.091089 -0.447214 -0.019172 -0.349745 -0.577350  1.732051 -0.577350
# 6  -1.091089  0.447214  0.336016 -0.343260 -0.577350 -0.577350  1.732051
# 7  -1.091089  1.341641 -0.327168 -1.355000 -0.577350 -0.577350 -0.577350
# 8  -0.654654 -1.341641 -0.995320 -1.104227  1.732051 -0.577350 -0.577350
# 9  -0.654654 -0.447214 -0.886031 -0.509721 -0.577350  1.732051 -0.577350
# 10 -0.654654  0.447214 -0.573068 -0.373525 -0.577350 -0.577350  1.732051
# 11 -0.654654  1.341641 -1.675891 -1.943021 -0.577350 -0.577350 -0.577350
# 12 -0.218218 -1.341641 -1.715632 -1.592803  1.732051 -0.577350 -0.577350
# 13 -0.218218 -0.447214 -1.608827 -0.455675 -0.577350  1.732051 -0.577350
# 14 -0.218218  0.447214 -0.826419  0.045872 -0.577350 -0.577350  1.732051
# 15 -0.218218  1.341641 -0.761839 -0.148694 -0.577350 -0.577350 -0.577350
# 16  0.218218 -1.341641  0.440338  0.400413  1.732051 -0.577350 -0.577350
# 17  0.218218 -0.447214  0.867557  0.850076 -0.577350  1.732051 -0.577350
# 18  0.218218  0.447214  1.284842  0.363662 -0.577350 -0.577350  1.732051
# 19  0.218218  1.341641  0.964427 -0.070868 -0.577350 -0.577350 -0.577350
# 20  0.654654 -1.341641  0.636561  0.636054  1.732051 -0.577350 -0.577350
# 21  0.654654 -0.447214  1.197908  1.077069 -0.577350  1.732051 -0.577350
# 22  0.654654  0.447214  0.909783  1.120306 -0.577350 -0.577350  1.732051
# 23  0.654654  1.341641  1.096070  0.789544 -0.577350 -0.577350 -0.577350
# 24  1.091089 -1.341641  0.942073  0.802515  1.732051 -0.577350 -0.577350
# 25  1.091089 -0.447214  1.217778  1.254340 -0.577350  1.732051 -0.577350
# 26  1.091089  0.447214  1.150715  1.120306 -0.577350 -0.577350  1.732051
# 27  1.091089  1.341641  0.758269  0.804677 -0.577350 -0.577350 -0.577350
# 28  1.527525 -1.341641  0.420467  0.891151  1.732051 -0.577350 -0.577350
# 29  1.527525 -0.447214  0.417983  1.243531 -0.577350  1.732051 -0.577350
# 30  1.527525  0.447214  0.653948  1.574292 -0.577350 -0.577350  1.732051
# 31  1.527525  1.341641  1.026523  1.007890 -0.577350 -0.577350 -0.577350
#
#           D4       yq2       yq3       yq4  new_variable
# 0  -0.577350 -0.576694 -0.576755 -0.576506     -0.377964
# 1  -0.577350  1.578206 -0.576755 -0.576506     -0.377964
# 2  -0.577350 -0.576694  1.578708 -0.576506     -0.377964
# 3   1.732051 -0.576694 -0.576755  1.669716     -0.377964
# 4  -0.577350 -0.576694 -0.576755 -0.576506     -0.377964
# 5  -0.577350  1.668475 -0.576755 -0.576506     -0.377964
# 6  -0.577350 -0.576694  1.663551 -0.576506     -0.377964
# 7   1.732051 -0.576694 -0.576755  1.606993     -0.377964
# 8  -0.577350 -0.576694 -0.576755 -0.576506     -0.377964
# 9  -0.577350  1.651692 -0.576755 -0.576506     -0.377964
# 10 -0.577350 -0.576694  1.660383 -0.576506     -0.377964
# 11  1.732051 -0.576694 -0.576755  1.544039     -0.377964
# 12 -0.577350 -0.576694 -0.576755 -0.576506     -0.377964
# 13 -0.577350  1.657362 -0.576755 -0.576506      2.645751
# 14 -0.577350 -0.576694  1.704275 -0.576506      2.645751
# 15  1.732051 -0.576694 -0.576755  1.736142      2.645751
# 16 -0.577350 -0.576694 -0.576755 -0.576506     -0.377964
# 17 -0.577350  1.794354 -0.576755 -0.576506     -0.377964
# 18 -0.577350 -0.576694  1.737534 -0.576506      2.645751
# 19  1.732051 -0.576694 -0.576755  1.744475     -0.377964
# 20 -0.577350 -0.576694 -0.576755 -0.576506     -0.377964
# 21 -0.577350  1.818168 -0.576755 -0.576506     -0.377964
# 22 -0.577350 -0.576694  1.816721 -0.576506     -0.377964
# 23  1.732051 -0.576694 -0.576755  1.836592     -0.377964
# 24 -0.577350 -0.576694 -0.576755 -0.576506     -0.377964
# 25 -0.577350  1.836767 -0.576755 -0.576506     -0.377964
# 26 -0.577350 -0.576694  1.816721 -0.576506     -0.377964
# 27  1.732051 -0.576694 -0.576755  1.838212     -0.377964
# 28 -0.577350 -0.576694 -0.576755 -0.576506     -0.377964
# 29 -0.577350  1.835633 -0.576755 -0.576506     -0.377964
# 30 -0.577350 -0.576694  1.864233 -0.576506     -0.377964
# 31  1.732051 -0.576694 -0.576755  1.859968     -0.377964

# %%
# Оценим модель регрессии model_1 для шкалированных показателей
model_1_scale = smf.ols('C ~ Y + D2 + D3 + D4', data=data_scale).fit()
print(model_1_scale.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      C   R-squared:                       0.771
# Model:                            OLS   Adj. R-squared:                  0.738
# Method:                 Least Squares   F-statistic:                     22.79
# Date:                Thu, 23 Oct 2025   Prob (F-statistic):           2.53e-08
# Time:                        13:07:26   Log-Likelihood:                -21.787
# No. Observations:                  32   AIC:                             53.57
# Df Residuals:                      27   BIC:                             60.90
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -4.441e-16      0.092  -4.83e-15      1.000      -0.189       0.189
# Y              0.8898      0.096      9.315      0.000       0.694       1.086
# D2            -0.1299      0.115     -1.129      0.269      -0.366       0.106
# D3            -0.0068      0.116     -0.059      0.954      -0.244       0.230
# D4             0.0944      0.113      0.837      0.410      -0.137       0.326
# ==============================================================================
# Omnibus:                        0.261   Durbin-Watson:                   0.722
# Prob(Omnibus):                  0.877   Jarque-Bera (JB):                0.451
# Skew:                          -0.114   Prob(JB):                        0.798
# Kurtosis:                       2.465   Cond. No.                         2.14
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
